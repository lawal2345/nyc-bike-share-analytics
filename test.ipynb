# %%
import requests
import json

# %%
station_info_url = "https://gbfs.lyft.com/gbfs/2.3/bkn/en/station_information.json"
station_status_url = "https://gbfs.lyft.com/gbfs/2.3/bkn/en/station_status.json"

# %%
# Get station information
info_response = requests.get(station_info_url)
info_data = info_response.json() # a dictionary

# %%
info_data
# Out:
# {'data': {'stations': [{'capacity': 43,
#     'lat': 40.72938685,
#     'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#      'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'name': 'E 14 St & Ave B',
#     'short_name': '5736.09',
#     'station_id': '66dc7ba2-0aca-11e7-82f6-3863bb44ef7c',
#     'lon': -73.97772429,
#     'region_id': '71'},
#    {'capacity': 17,
#     'lat': 40.70636,
#     'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#      'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'name': 'Suydam St & St Nicholas Ave',
#     'short_name': '5043.06',
#     'station_id': '498d7e8e-5164-4f26-9ce6-399947d73b1a',
#     'lon': -73.91945,
#     'region_id': '71'},
#    {'capacity': 35,
#     'lat': 40.76211,
#     'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#      'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'name': '31 St & Broadway',
#     'short_name': '6789.20',
# ...

# %%
info_data.keys()
# Out:
# dict_keys(['data', 'last_updated', 'ttl', 'version'])

# %%
info_data['data']['stations'][0]
# Out:
# {'capacity': 43,
#  'lat': 40.72938685,
#  'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#   'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#  'name': 'E 14 St & Ave B',
#  'short_name': '5736.09',
#  'station_id': '66dc7ba2-0aca-11e7-82f6-3863bb44ef7c',
#  'lon': -73.97772429,
#  'region_id': '71'}

# %%
status_response = requests.get(station_status_url)
status_data = status_response.json()

# %%
status_data
# Out:
# {'data': {'stations': [{'num_ebikes_available': 0,
#     'last_reported': 86400,
#     'num_docks_disabled': 0,
#     'is_renting': 0,
#     'num_bikes_disabled': 0,
#     'num_bikes_available': 0,
#     'station_id': '66dc7ba2-0aca-11e7-82f6-3863bb44ef7c',
#     'vehicle_types_available': [{'vehicle_type_id': '1', 'count': 0},
#      {'vehicle_type_id': '2', 'count': 0}],
#     'num_docks_available': 0,
#     'is_returning': 0,
#     'is_installed': 0},
#    {'num_ebikes_available': 0,
#     'last_reported': 1759761514,
#     'num_docks_disabled': 0,
#     'is_renting': 0,
#     'num_bikes_disabled': 0,
#     'num_bikes_available': 0,
#     'station_id': '498d7e8e-5164-4f26-9ce6-399947d73b1a',
#     'vehicle_types_available': [{'vehicle_type_id': '1', 'count': 0},
#      {'vehicle_type_id': '2', 'count': 0}],
#     'num_docks_available': 0,
#     'is_returning': 0,
#     'is_installed': 0},
#    {'num_ebikes_available': 0,
#     'last_reported': 86400,
# ...
